# %%
import uuid
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm
from arango import ArangoClient
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from transformers import pipeline, AutoTokenizer, AutoModel

# %%
raw_df = pd.read_csv('./data/raw.csv')

# %%
raw_df.head()
# Out:
#   country_of_destination country_of_origin  hs6_code  \
# 0                     CA                US    321410
# 1                    NaN               NaN    320890
# 2                     US                IN    390940
# 3                     US                CN    731100
# 4                     CH                IN    250590
#
#                                     receiver_address  \
# 0  95 SUNRAY STREET, WHITBY, ON, L1N9C9, CANADA T...
# 1                                              China
# 2                                      United States
# 3  OF RPM WOOD FINISHES GROUP 3190 HICKORY BLVD H...
# 4                                        Switzerland
#
#                         receiver_id                       receiver_name  \
# 0  4bd999c0cb4346ce047f99a692ec3191                        Stonhard Ltd
# 1  8b1f537a8eeca839cff8a99e08b35690  CARBOLINE DALIAN PAINT COMPANY LTD
# 2  1670c05b29762f5d4ab8980d267bd482                      Rust-Oleum Llc
# 3  210f645e15d75833b25090f2ae509eda       Mohawk Finishing Products Inc
# 4  7150428f8927c86ac11c64c1bb9b0285             Vandex International AG
#
#                                       sender_address  \
# 0              60 MARKET SAUQRE, BELIZE CITY, BELIZE
# 1  Plot O 356 &357, Sidco Indl Estate Ambattur Ch...
# 2  204, Monarch Chambers, Marol Maroshi Road, Mum...
# 3  YUNG-SHI BLVD, SHI-WAN TOWN, PO-LO COUNTY HUI-...
# 4  FLOWCRETE INDIA PRIVATE LIMITEDNEW NO.36 OLD N...
#
#                           sender_id  \
# 0  52c8642c34649eafe2d044eee3d884e1
# 1  831a31a1466f0ace3eb20b52d4575f92
# 2  f580bc1756d06768c94634b0332e1871
# 3  149081be00548b006dc38a88264eae32
# 4  f4864ac3d5d716cc586d60afe8a403ef
#
#                                   sender_name    tier transaction_date
# 0                      Global Fire Protection  t1->t0         11/30/18
# 1           Carboline (India) Private Limited  t1->t0           5/2/18
# 2  Paladin Paints & Chemicals Private Limited  t1->t0           5/2/17
# 3               Alpha Pacific Group Pte. Ltd.  t1->t0           5/8/16
# 4            TREMCO CPG INDIA PRIVATE LIMITED  t1->t0          5/26/17

# %%
sender_df = raw_df[['sender_id', 'sender_address', 'country_of_origin']].copy()
sender_df.rename(columns={'sender_id':'organization_id', 'sender_address':'address', 'country_of_origin':'country'}, inplace=True)

# %%
receiver_df = raw_df[['receiver_id', 'receiver_address', 'country_of_destination']].copy()
receiver_df.rename(columns={'receiver_id':'organization_id', 'receiver_address':'address', 'country_of_destination':'country'}, inplace=True)

# %%
address_df = pd.concat([sender_df, receiver_df], ignore_index=True).drop_duplicates(ignore_index=True)

# %%
address_df.head()
# Out:
#                     organization_id  \
# 0  52c8642c34649eafe2d044eee3d884e1
# 1  831a31a1466f0ace3eb20b52d4575f92
# 2  f580bc1756d06768c94634b0332e1871
# 3  149081be00548b006dc38a88264eae32
# 4  f4864ac3d5d716cc586d60afe8a403ef
#
#                                              address country
# 0              60 MARKET SAUQRE, BELIZE CITY, BELIZE      US
# 1  Plot O 356 &357, Sidco Indl Estate Ambattur Ch...     NaN
# 2  204, Monarch Chambers, Marol Maroshi Road, Mum...      IN
# 3  YUNG-SHI BLVD, SHI-WAN TOWN, PO-LO COUNTY HUI-...      CN
# 4  FLOWCRETE INDIA PRIVATE LIMITEDNEW NO.36 OLD N...      IN

# %%
address_df[address_df.country.isna()].address.iloc[8]
# Out:
# 'Russian Federation'

# %%
address_df.shape
# Out:
# (2546, 3)

# %%
# ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")

# %%
# # def extract_country(address):
# #     # Apply NER to the address
# #     ner_results = ner_pipeline(address)
    
# #     # Clean up the results to avoid extra spaces
# #     locations = [entity['word'].strip() for entity in ner_results if 'LOC' in entity['entity']]
    
# #     # Join the locations detected
# #     return ' '.join(locations) if locations else "Unknown"
# def extract_country_code(address):
#     # Run NER on the input address
#     entities = ner_pipeline(address)
    
#     # Extract unique country identifiers (assuming they have been recognized)
#     country_codes = []
#     for entity in entities:
#         if entity['entity'] == 'B-LOC' or entity['entity'] == 'I-LOC':
#             country_codes.append(entity['word'])
#     print(entities)
    
#     # Convert extracted country names to codes
#     unique_country_codes = set(country_codes)
#     return list(unique_country_codes)

# %%
# site_df['extracted_country'] = site_df['address'].apply(extract_country)

# %%
# extract_country_code("60 MARKET SAUQRE, BELIZE CITY, BELIZE")

# %%
address_df.country.value_counts()
# Out:
# country
# US    545
# GB    139
# CN    127
# IT    123
# DE    104
#      ...
# DJ      1
# IR      1
# SZ      1
# ET      1
# GT      1
# Name: count, Length: 85, dtype: int64

# %%
address_df.country.isna().mean()
# Out:
# np.float64(0.26983503534956793)

# %%
address_df.country.str.len().unique()
# Out:
# array([ 2., nan])

# %%
address_df[address_df.country.isna()]
# Out:
#                        organization_id  \
# 1     831a31a1466f0ace3eb20b52d4575f92
# 8     c61f1f95b68a9c7caf0e642be8e36e07
# 13    140c63ccedc8eac19c62398e6c1af6d0
# 21    80e44a0be590c7c9ae03e5d83ad0a6e5
# 28    233cbea86cfae088bcd6680aadd4fcc4
# ...                                ...
# 2500  1d73f9dd5be62952c256d617d199aa24
# 2507  59b9fcc328c9c3edd4c7d29c21f1cf28
# 2508  183a723c366275c52a311db74d68402b
# 2509  1d73f9dd5be62952c256d617d199aa24
# 2520  905b895875ee85a433c0e7ede23788a4
#
#                                                 address country
# 1     Plot O 356 &357, Sidco Indl Estate Ambattur Ch...     NaN
# 8               CR 73   48   46 BRR NORMANDIA II SECTOR     NaN
# 13    AVENIDA LAS MISIONES 21 PARQUE INDUSTRIAL BERN...     NaN
# 21    S. SUKHATME ) 1105/3 MANAS NARGIS  DUTTA RD. M...     NaN
# 28    ADD: NO.3 OF GONGYE 3RD ROAD. BIJIA INDUSTRIAL...     NaN
# ...                                                 ...     ...
# 2500  PP 8105 95TH STREET PLEASANT PRAIRI PRAIRIE WI...     NaN
# 2507  8905 WOLLARD BLVD RICHMOND, MO  640 85 TAX ID ...     NaN
# 2508                                           Malaysia     NaN
# 2509  8105 95TH STREET PLEASANT PRAIRIE  WI 53158 UN...     NaN
# 2520  KENNEDY NORTE AV JOSE CASTILLO MZ 601 VILLA 14...     NaN
#
# [687 rows x 3 columns]

# %%
address_df[address_df.country.isna()].sample(1)
# Out:
#                        organization_id address country
# 2229  1184d782d482ec68beddd3469ccad59e   China     NaN

# %%
model_df = address_df[~address_df.country.isna()].reset_index(drop=True)

# %%
model_df
# Out:
#                        organization_id  \
# 0     52c8642c34649eafe2d044eee3d884e1
# 1     f580bc1756d06768c94634b0332e1871
# 2     149081be00548b006dc38a88264eae32
# 3     f4864ac3d5d716cc586d60afe8a403ef
# 4     a26b29b47ac4c97f4285096343d85b79
# ...                                ...
# 1854  00750bb980757fd8535d73b90d6608c8
# 1855  2c398f54dacfc67b9fbe414565285dba
# 1856  2c398f54dacfc67b9fbe414565285dba
# 1857  1b4334d45be8824a1f6b071a9a2f75a8
# 1858  2c398f54dacfc67b9fbe414565285dba
#
#                                                 address country
# 0                 60 MARKET SAUQRE, BELIZE CITY, BELIZE      US
# 1     204, Monarch Chambers, Marol Maroshi Road, Mum...      IN
# 2     YUNG-SHI BLVD, SHI-WAN TOWN, PO-LO COUNTY HUI-...      CN
# 3     FLOWCRETE INDIA PRIVATE LIMITEDNEW NO.36 OLD N...      IN
# 4     RUA DO RIBEIRINHO, 202 APARTADO 13   S.PAIO OL...      PT
# ...                                                 ...     ...
# 1854  4518 HAMILTON AVENUE CLEVELAND OHIO 44114 USA ...      US
# 1855  19320 REDWOOD RD.  44110-2799 CLEVELAND CLEVELAND      US
# 1856  19218 REDWOOD ROAD  CLEVELAND, OH CLEVELANDOH ...      US
# 1857                                      United States      US
# 1858  19218 REDWOOD ROAD CLEVELAND, OH CUYAHOGA, OH ...      US
#
# [1859 rows x 3 columns]

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', clean_up_tokenization_spaces=True)

# %%
model = AutoModel.from_pretrained('bert-base-uncased')

# %%
def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=64)
    with torch.no_grad():
        outputs = model(**inputs)
    # Use the CLS token's hidden state as the sentence embedding
    return outputs.last_hidden_state[:, 0, :].squeeze().numpy()

# %%
embeddings = np.array([get_embedding(address) for address in tqdm(model_df['address'], desc="Extracting embeddings")])
# Out:
# Extracting embeddings: 100%|██████████| 1859/1859 [02:25<00:00, 12.80it/s]

# %%
embeddings.shape
# Out:
# (1859, 768)

# %%
pca = PCA(n_components=50)  # You can adjust n_components based on variance explained
embeddings_reduced = pca.fit_transform(embeddings)

# %%
embeddings_reduced.shape
# Out:
# (1859, 50)

# %%
le=LabelEncoder()

# %%
model_df['country_encoded'] = le.fit_transform(model_df['country'])

# %%
X_train, X_test, y_train, y_test = train_test_split(embeddings_reduced, model_df['country_encoded'], test_size=0.2, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_split=5, random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=5, random_state=42)

# %%
train_pred = clf.predict(X_train)
train_pred_labels = le.inverse_transform(train_pred)
train_labels = le.inverse_transform(y_train)
print(classification_report(train_labels, train_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#           AE       0.00      0.00      0.00        17
#           AR       0.00      0.00      0.00         6
#           AT       0.00      0.00      0.00        11
#           AU       0.00      0.00      0.00        15
#           AZ       0.00      0.00      0.00         1
#           BE       1.00      0.42      0.60        33
#           BG       0.00      0.00      0.00         1
#           BR       0.00      0.00      0.00         6
#           BY       0.00      0.00      0.00         2
#           CA       0.00      0.00      0.00        19
#           CH       0.00      0.00      0.00        13
#           CL       0.00      0.00      0.00         1
#           CN       0.86      0.74      0.79       104
#           CO       0.00      0.00      0.00         9
#           CR       0.00      0.00      0.00         4
#           CU       0.00      0.00      0.00         2
#           CY       0.00      0.00      0.00         1
#           CZ       0.00      0.00      0.00         7
#           DE       0.86      0.87      0.86        83
#           DJ       0.00      0.00      0.00         1
#           DK       0.00      0.00      0.00         4
#           DO       0.00      0.00      0.00         1
#           EC       0.00      0.00      0.00         1
#           EE       0.00      0.00      0.00         1
#           ES       1.00      0.04      0.08        25
#           FI       0.00      0.00      0.00         5
#           FR       0.00      0.00      0.00        31
#           GB       0.77      0.81      0.79       121
#           GY       0.00      0.00      0.00         1
#           HK       1.00      0.61      0.76        28
#           HR       0.00      0.00      0.00         1
#           HU       0.00      0.00      0.00        11
#           ID       0.00      0.00      0.00         3
#           IE       0.00      0.00      0.00         6
#           IL       0.00      0.00      0.00         2
#           IN       0.93      0.61      0.74        62
#           IR       0.00      0.00      0.00         1
#           IT       0.98      0.93      0.95        88
#           JP       0.00      0.00      0.00        11
#           KR       1.00      0.50      0.67        14
#           KZ       0.00      0.00      0.00         3
#           LI       0.00      0.00      0.00         1
#           LR       0.00      0.00      0.00         1
#           LU       0.00      0.00      0.00         2
#           MN       0.00      0.00      0.00         1
#           MT       0.00      0.00      0.00         1
#           MX       0.95      0.70      0.80        53
#           MY       0.00      0.00      0.00         8
#           NG       0.00      0.00      0.00         1
#           NL       0.97      0.58      0.72        59
#           NO       0.00      0.00      0.00        11
#           NP       0.00      0.00      0.00         4
#           NZ       0.00      0.00      0.00         1
#           PA       0.00      0.00      0.00         5
#           PH       0.00      0.00      0.00         2
#           PT       0.00      0.00      0.00         2
#           RO       0.00      0.00      0.00        12
#           RS       0.00      0.00      0.00         3
#           RU       0.00      0.00      0.00         2
#           SA       0.00      0.00      0.00         2
#           SD       0.00      0.00      0.00         1
#           SE       1.00      0.82      0.90        17
#           SG       0.00      0.00      0.00         9
#           SI       0.00      0.00      0.00         7
#           SK       0.00      0.00      0.00         4
#           SM       0.00      0.00      0.00         1
#           SS       0.00      0.00      0.00         1
#           SV       0.00      0.00      0.00         3
#           SZ       0.00      0.00      0.00         1
#           TH       0.00      0.00      0.00        12
#           TR       0.00      0.00      0.00        10
#           TT       0.00      0.00      0.00         2
#           TW       1.00      0.18      0.30        28
#           TZ       0.00      0.00      0.00         1
#           US       0.46      0.95      0.62       444
#           UY       0.00      0.00      0.00         2
#           VN       0.00      0.00      0.00        10
#           ZA       0.00      0.00      0.00         7
#
#     accuracy                           0.62      1487
#    macro avg       0.16      0.11      0.12      1487
# weighted avg       0.57      0.62      0.55      1487
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_pred = clf.predict(X_test)
y_pred_labels = le.inverse_transform(y_pred)
y_test_labels = le.inverse_transform(y_test)
print(classification_report(y_test_labels, y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#           AE       0.00      0.00      0.00         5
#           AR       0.00      0.00      0.00         2
#           AT       0.00      0.00      0.00         2
#           AU       0.00      0.00      0.00         7
#           BE       1.00      0.50      0.67         4
#           BR       0.00      0.00      0.00         1
#           CA       0.00      0.00      0.00         4
#           CG       0.00      0.00      0.00         1
#           CH       0.00      0.00      0.00        10
#           CL       0.00      0.00      0.00         3
#           CN       0.77      0.43      0.56        23
#           CO       0.00      0.00      0.00         2
#           CY       0.00      0.00      0.00         2
#           CZ       0.00      0.00      0.00         3
#           DE       0.79      0.52      0.63        21
#           DK       0.00      0.00      0.00         3
#           DO       0.00      0.00      0.00         2
#           ES       0.00      0.00      0.00         5
#           ET       0.00      0.00      0.00         1
#           FI       0.00      0.00      0.00         1
#           FR       0.00      0.00      0.00         7
#           GB       0.60      0.67      0.63        18
#           GT       0.00      0.00      0.00         1
#           HK       1.00      0.60      0.75         5
#           HR       0.00      0.00      0.00         1
#           HU       0.00      0.00      0.00         2
#           IE       0.00      0.00      0.00         2
#           IN       1.00      0.53      0.69        19
#           IT       0.94      0.91      0.93        35
#           JP       0.00      0.00      0.00         4
#           KR       0.00      0.00      0.00         5
#           LI       0.00      0.00      0.00         1
#           MX       0.73      0.62      0.67        13
#           MY       0.00      0.00      0.00         2
#           NL       0.80      0.33      0.47        12
#           NO       0.00      0.00      0.00         3
#           PL       0.00      0.00      0.00         4
#           RO       0.00      0.00      0.00         2
#           SA       0.00      0.00      0.00         1
#           SE       1.00      1.00      1.00         4
#           SG       0.00      0.00      0.00        10
#           SN       0.00      0.00      0.00         1
#           TH       0.00      0.00      0.00         4
#           TJ       0.00      0.00      0.00         1
#           TM       0.00      0.00      0.00         1
#           TR       0.00      0.00      0.00         4
#           TW       1.00      0.50      0.67         2
#           US       0.38      0.95      0.54       101
#           UY       0.00      0.00      0.00         1
#           VN       0.00      0.00      0.00         2
#           ZA       0.00      0.00      0.00         2
#
#     accuracy                           0.52       372
#    macro avg       0.20      0.15      0.16       372
# weighted avg       0.45      0.52      0.44       372
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def predict_country_code(address):
    embedding = get_embedding(address)
    embedding_reduced = pca.transform([embedding])  # Apply PCA transformation
    prediction = clf.predict(embedding_reduced)
    return le.inverse_transform(prediction)[0]

# %%
class EmbeddingExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, model_name='bert-base-uncased'):
        self.tokenizer = AuthTokenizer.from_pretrained(model_name, clean_up_tokenization_spaces=True)
        self.model = AutoModel.from_pretrained(model_name)

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        embeddings = []
        for text in tqdm(X, desc="Extracting embeddings"):
            inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=64)
            with torch.no_grad():
                outputs = self.model(**outputs)
            embeddings.append(outputs.last_hidden_state[:, 0, :].squeeze().numpy())
        return np.array(embeddings)

# %%
class AddressCountryClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, n_components=50, n_estimators=100)
        self.n_components = n_components
        self.n_estimators = n_estimators
        self.le = LabelEncoder()
        self.embeddings_model = None
        self.tokenizer = None
        self.pca = PCA(n_components = self.n_components)
        self.clf = RandomForestClassifier(n_estimators=self.n_estimators, random_state=42)

    def fit(self, X, y):
        self.le.fit(y)

        self.tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
        self.model = AutoModel.from_pretrained('bert-base-uncased')

        embeddings = np.array([self.get_embedding(address) for address in tqdm(X, desc="Extracting embeddings")])

        embeddings_reduced = self.pca.fit_transform(embeddings)

        self.clf.fit(embeddings_reduced, self.le.transform(y))

        return self

    def predict(self, X):
        embeddings = np.array([self.get_embedding(address) for address in tqdm(X, desc="Extracting embeddings")])
        embeddings_reduced = self.pca.transform(embeddings)

# %%
predict_country_code("Guanzhou")
# Out:
# 'CN'

# %%
predict_country_code("Guanhou")
# Out:
# 'CN'

# %%
predict_country_code("New York")
# Out:
# 'US'

# %%
predict_country_code("United Kingdom")
# Out:
# 'GB'

# %%
def infer_missing_country_codes(df):
    missing_mask = df['country'].isnull()  # Mask for missing country codes
    addresses_to_predict = df.loc[missing_mask, 'address']
    
    # Get embeddings and reduce dimensionality for missing addresses in bulk
    embeddings = np.array([get_embedding(address) for address in tqdm(addresses_to_predict, desc="Extracting embeddings"]))
    embeddings_reduced = pca.transform(embeddings)
    
    # Predict country codes in bulk
    predictions = clf.predict(embeddings_reduced)
    predicted_country_codes = le.inverse_transform(predictions)
    
    # Fill the missing country codes
    df.loc[missing_mask, 'country'] = predicted_country_codes
    
    return df

# %%
address_df_filled = infer_missing_country_codes(address_df)

# %%
address_df_filled.to_csv('./data/address.csv', index=False)

# %%
address_df_filled.country.isna().sum()
# Out:
# np.int64(0)

# %%
address_df_filled
# Out:
#                        organization_id  \
# 0     52c8642c34649eafe2d044eee3d884e1
# 1     831a31a1466f0ace3eb20b52d4575f92
# 2     f580bc1756d06768c94634b0332e1871
# 3     149081be00548b006dc38a88264eae32
# 4     f4864ac3d5d716cc586d60afe8a403ef
# ...                                ...
# 2541  00750bb980757fd8535d73b90d6608c8
# 2542  2c398f54dacfc67b9fbe414565285dba
# 2543  2c398f54dacfc67b9fbe414565285dba
# 2544  1b4334d45be8824a1f6b071a9a2f75a8
# 2545  2c398f54dacfc67b9fbe414565285dba
#
#                                                 address country
# 0                 60 MARKET SAUQRE, BELIZE CITY, BELIZE      US
# 1     Plot O 356 &357, Sidco Indl Estate Ambattur Ch...      US
# 2     204, Monarch Chambers, Marol Maroshi Road, Mum...      IN
# 3     YUNG-SHI BLVD, SHI-WAN TOWN, PO-LO COUNTY HUI-...      CN
# 4     FLOWCRETE INDIA PRIVATE LIMITEDNEW NO.36 OLD N...      IN
# ...                                                 ...     ...
# 2541  4518 HAMILTON AVENUE CLEVELAND OHIO 44114 USA ...      US
# 2542  19320 REDWOOD RD.  44110-2799 CLEVELAND CLEVELAND      US
# 2543  19218 REDWOOD ROAD  CLEVELAND, OH CLEVELANDOH ...      US
# 2544                                      United States      US
# 2545  19218 REDWOOD ROAD CLEVELAND, OH CUYAHOGA, OH ...      US
#
# [2546 rows x 3 columns]

# %%
site_df = address_df_filled[['organization_id', 'country']].drop_duplicates()

# %%
site_df.insert(0, '_key', [uuid.uuid4().hex for _ in range(len(site_df))])

# %%
site_df['organization_id'] = 'organizations/' + site_df['organization_id']

# %%
site_df
# Out:
#                                   _key  \
# 0     5f5d506385474ebf9cf2c97e748dd07b
# 1     54c78f96680e4b7b912a28ba11ddc0eb
# 2     8d6cddc3df8040b3b15f6eb78b419edd
# 3     093b7092701f43fbaad91d6faf8a20e9
# 4     8853aa0467ee4d1c97bbf341c4a1927c
# ...                                ...
# 2522  2be5373e281249ae851b80111d3e7579
# 2524  fcdc3607e8e6491c83f6a71362b215c1
# 2525  972e3126b93a40d59f6fb42047a0baa0
# 2539  034a81c43ff0453dac52d247f3cbd226
# 2544  18710e5c6d804f3a8dacecdcb40c294d
#
#                                      organization_id country
# 0     organizations/52c8642c34649eafe2d044eee3d884e1      US
# 1     organizations/831a31a1466f0ace3eb20b52d4575f92      US
# 2     organizations/f580bc1756d06768c94634b0332e1871      IN
# 3     organizations/149081be00548b006dc38a88264eae32      CN
# 4     organizations/f4864ac3d5d716cc586d60afe8a403ef      IN
# ...                                              ...     ...
# 2522  organizations/2fc4208e46b525d0b90e4662a7d7e2f4      US
# 2524  organizations/d3a2485b31c1e99218252f115a29d02e      US
# 2525  organizations/ba616735135653cb6ff28ca5856e6599      US
# 2539  organizations/68b95e65719c3deb6c32fda273487981      US
# 2544  organizations/1b4334d45be8824a1f6b071a9a2f75a8      US
#
# [2149 rows x 3 columns]

# %%
client = ArangoClient(hosts="https://2ae4f052d710.arangodb.cloud:8529")

db = client.db('machine_learning', username='lab_test', password='z-rRdN-Enf4qQwybGiVdbG')

# %%
# db.delete_collection('sites')
# Out:
# True

# %%
if not db.has_collection('sites'):
    sites = db.create_collection('sites')
else:
    sites = db.collection('sites')

# %%
sites_list = site_df.to_dict(orient='records')

# %%
# sites_list
sites.insert_many(sites_list, overwrite_mode="replace", silent=True)
# Out:
# True
